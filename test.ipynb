# %%
from grocerify.helper import Helper

# %%
helper = Helper()

# %%
products = helper.search('tim tam')
# Out:
# Error processing product data: Product.__init__() got an unexpected keyword argument 'priec_per_unit'. Did you mean 'price_per_unit'?
# Error processing product data: Product.__init__() got an unexpected keyword argument 'priec_per_unit'. Did you mean 'price_per_unit'?
# Error processing product data: Product.__init__() got an unexpected keyword argument 'priec_per_unit'. Did you mean 'price_per_unit'?
# Error processing product data: Product.__init__() got an unexpected keyword argument 'priec_per_unit'. Did you mean 'price_per_unit'?
# Error processing product data: Product.__init__() got an unexpected keyword argument 'priec_per_unit'. Did you mean 'price_per_unit'?
# Error processing product data: Product.__init__() got an unexpected keyword argument 'priec_per_unit'. Did you mean 'price_per_unit'?
# Error processing product data: Product.__init__() got an unexpected keyword argument 'priec_per_unit'. Did you mean 'price_per_unit'?
# ...

# %%
for item in products:
    print(item)
# Out:
# Product Information:
# Name: Arnott's Tim Tam Original Chocolate Biscuits
# Price: $6
# Store: woolworths
# Size: 100G
# Image URL: https://cdn0.woolworths.media/content/wowproductimages/large/036066.jpg
# Product Information:
# Name: Arnott's Tim Tam Double Chocolate Biscuits
# Price: $6
# Store: woolworths
# Size: 100G
# Image URL: https://cdn0.woolworths.media/content/wowproductimages/large/032257.jpg
# Product Information:
# Name: Arnott's Tim Tam Chewy Caramel Chocolate Biscuits
# Price: $6
# Store: woolworths
# Size: 100G
# Image URL: https://cdn0.woolworths.media/content/wowproductimages/large/117833.jpg
# Product Information:
# Name: Arnott's Tim Tam White Chocolate Biscuits
# Price: $6
# Store: woolworths
# Size: 100G
# Image URL: https://cdn0.woolworths.media/content/wowproductimages/large/332047.jpg
# Product Information:
# Name: Arnott's Tim Tam Dark Chocolate Biscuits
# Price: $6
# Store: woolworths
# Size: 100G
# ...

# %%
print(products[0])
# Out:
# Product Information:
# Name: Arnott's Tim Tam Original Chocolate Biscuits
# Price: $6
# Store: woolworths
# Size: 100G
# Image URL: https://cdn0.woolworths.media/content/wowproductimages/large/036066.jpg
